# %% [markdown]
# # Load Packages

# %%
import os
os.environ['SM_FRAMEWORK'] = 'tf.keras'

# %%
# Import packages
import tensorflow as tf
import numpy as np
import pandas as pd
import PIL
import pathlib
from tensorflow import keras
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

import segmentation_models as sm
sm.set_framework('tf.keras')
from tensorflow.keras.applications import vgg16
from sklearn.metrics import *
# Out:
# 2025-12-11 08:08:55.872379: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-11 08:08:56.001444: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-11 08:08:56.029700: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-11 08:08:56.516783: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2025-12-11 08:08:56.516834: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2025-12-11 08:08:56.516838: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Segmentation Models: using `tf.keras` framework.

# %%
# Configuration
base_dir = r"/root/attention-mechanism-unet-main/LoveDA_Processed/"

# %% [markdown]
# # Functions

# %%
'''
  Returns an image plot of mask prediction
'''

def reconstruct_image(model, image, rounded=False):

  # Find model prediction
  reconstruction = model.predict(image).reshape(image.shape[1], image.shape[2])
  # Standardise between 0-1
  reconstruction = reconstruction/np.max(reconstruction)

  # Round to 0-1, binary pixel-by-pixel classification 
  if rounded:
    reconstruction = np.round(reconstruction)

  # Plot reconstructed mask (prediction)
  plt.imshow(reconstruction)

# %%
'''
  Returns array of mask prediction, given model and image
'''
def reconstruct_array(model, image, rounded=False):

  # Find model prediction
  reconstruction = model.predict(image).reshape(image.shape[1], image.shape[2])

  if rounded:
    reconstruction = np.round(reconstruction)

  return reconstruction # Returns array

# %%
'''
  Metric functions for evaluation
'''

def score_eval(model, image, mask): # Gives score of mask vs prediction
  if type(image) != list:   
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return accuracy_score(mask.flatten(), reconstruction)

  else: # If a list of images input, find accuracy for each
    scores = []
    for i in range(len(image)):
      reconstruction = model.predict(image[i].reshape(1, 512, 512, 3))
      reconstruction = np.round(reconstruction).flatten()

      scores.append(accuracy_score(mask[i].flatten(), reconstruction))

    return scores

def recall_eval(model, image, mask): # Find recall score
  if type(image) != list:   
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return recall_score(mask.flatten(), reconstruction, average='weighted')

  else: # If a list of images input, find accuracy for each
    recall = []
    for i in range(len(image)):
        reconstruction = model.predict(image[i]).reshape(mask[i].shape[1], mask[i].shape[2])
        reconstruction = np.round(reconstruction).flatten()

        recall.append(recall_score(mask[i].flatten(), reconstruction, average='weighted'))

    return recall

def precision_eval(model, image, mask): # Find precision score
  if type(image) != list:   
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return precision_score(mask.flatten(), reconstruction, average='weighted')

  else: # If a list of images input, find accuracy for each
    precision = []
    for i in range(len(image)):
        reconstruction = model.predict(image[i]).reshape(mask[i].shape[1], mask[i].shape[2])
        reconstruction = np.round(reconstruction).flatten()

        precision.append(precision_score(mask[i].flatten(), reconstruction, average='weighted'))

    return precision

def f1_score_eval(model, image, mask): # Find F1-score
    prec = np.mean(precision_eval(model, image, mask))
    rec = np.mean(recall_eval(model, image, mask))

    if prec + rec == 0:
        return 0

    return 2 * (prec * rec) / (prec + rec)

def f1_score_eval_basic(precision, recall):
    prec = np.mean(precision)
    rec = np.mean(recall)

    if prec + rec == 0:
        return 0

    return 2 * (prec * rec) / (prec + rec)

def produce_mask(image): # Outputs rounded image (binary)
  return np.round(image)

# %% [markdown]
# # Ingest and Process LoveDA Dataset

# %%
# Ingest images

## Training images
training_images_list = os.listdir(r"{}Training/images/".format(base_dir))
training_masks_list = training_images_list  # LoveDA: same filename for image and mask
training_images = []
for n in training_images_list:
  im = PIL.Image.open(r"{}Training/images/{}".format(base_dir,n))
  training_images.append(im)

## Training masks
training_masks = []
for n in training_masks_list:
  im = PIL.Image.open(r"{}Training/masks/{}".format(base_dir,n))
  training_masks.append(im)

## Test images and masks (LoveDA has test masks)
test_images_list = os.listdir(r"{}Test/images/".format(base_dir))
test_masks_list = test_images_list
test_images = []
for n in test_images_list:
  im = PIL.Image.open(r"{}Test/images/{}".format(base_dir,n))
  test_images.append(im)

test_masks = []
for n in test_masks_list:
  im = PIL.Image.open(r"{}Test/masks/{}".format(base_dir,n))
  test_masks.append(im)

## Validation images
validation_images_list = os.listdir(r"{}Validation/images/".format(base_dir))
validation_masks_list = validation_images_list  # LoveDA: same filename
validation_images = []
for n in validation_images_list:
  im = PIL.Image.open(r"{}Validation/images/{}".format(base_dir,n))
  validation_images.append(im)

## Validation masks
validation_masks = []
for n in validation_masks_list:
  im = PIL.Image.open(r"{}Validation/masks/{}".format(base_dir,n))
  validation_masks.append(im)

# %%
# Pre-process data, normalise and reshape
for i in range(len(training_images)):
  training_images[i] = np.array(training_images[i])/255
  training_images[i] = training_images[i].reshape(512,512,3)
  training_images[i] = training_images[i].astype('float32')

for i in range(len(training_masks)):
  training_masks[i] = np.array(training_masks[i])/255.0  # LoveDA: 0/255 -> 0/1
  training_masks[i] = training_masks[i].reshape(512,512,1)
  training_masks[i] = training_masks[i].astype('float32')

for i in range(len(validation_images)):
  validation_images[i] = np.array(validation_images[i])/255
  validation_images[i] = validation_images[i].reshape(1,512,512,3)
  validation_images[i] = validation_images[i].astype('float32')

for i in range(len(validation_masks)):
  validation_masks[i] = np.array(validation_masks[i])/255.0  # LoveDA: 0/255 -> 0/1
  validation_masks[i] = validation_masks[i].reshape(1,512,512,1)
  validation_masks[i] = validation_masks[i].astype('float32')

for i in range(len(test_images)):
  test_images[i] = np.array(test_images[i])/255
  test_images[i] = test_images[i].reshape(1,512,512,3)
  test_images[i] = test_images[i].astype('float32')

for i in range(len(test_masks)):
  test_masks[i] = np.array(test_masks[i])/255.0  # LoveDA: 0/255 -> 0/1
  test_masks[i] = test_masks[i].reshape(1,512,512,1)
  test_masks[i] = test_masks[i].astype('float32')

# LoveDA dataset already split into 70/20/10, no need to reorganize
print(f"Training: {len(training_images)} images")
print(f"Validation: {len(validation_images)} images")
print(f"Test: {len(test_images)} images")
# Out:
# Training: 70 images
# Validation: 20 images
# Test: 10 images

# %%
# Create TensorFlow datasets for validation sets
validation_df = tf.data.Dataset.from_tensor_slices((validation_images, validation_masks))
# Out:
# 2025-12-11 08:11:40.524003: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2027] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-12-11 08:11:40.525170: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-11 08:11:40.547739: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2027] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2025-12-11 08:13:14.915113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 29881 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5090, pci bus id: 0000:b8:00.0, compute capability: 12.0

# %%
#
# Data loader/generator from: https://github.com/bragagnololu/UNet-defmapping.git
#

def adjustData(img, mask, num_class):
  
    mask[mask > 0.5] = 1 # FOREST
    mask[mask <= 0.5] = 0 # NON-FOREST

    return (img,mask)

def trainGenerator(batch_size,
                   image_array,
                   mask_array,
                   aug_dict,
                   image_save_prefix  = "image",
                   mask_save_prefix  = "mask",
                   num_class = 2,
                   save_to_dir = None,
                   target_size = (512,512),
                   seed = 1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow(image_array,
                                           batch_size = batch_size,
                                           save_to_dir = save_to_dir,
                                           save_prefix = image_save_prefix,
                                           seed = seed) 

    mask_generator = mask_datagen.flow(mask_array,
                                           batch_size = batch_size,
                                           save_to_dir = save_to_dir,
                                           save_prefix = mask_save_prefix,
                                           seed = seed)
    
    train_generator = zip(image_generator, mask_generator)
    
    for (img,mask) in train_generator: 
        img, mask = adjustData(img, mask, num_class)
        yield (img, mask)

# %%
#
# Produce generators for training images
#

t_images = np.stack(training_images)
t_masks = np.stack(training_masks)

v_images = np.stack(validation_images)
v_masks = np.stack(validation_masks)

# Set parameters for data augmentation
data_gen_args = dict(rotation_range=180,
                    width_shift_range=0.25,
                    height_shift_range=0.25,
                    shear_range=0.25,
                    zoom_range=0.25,
                    horizontal_flip=True,
                    vertical_flip = True,
                    fill_mode='reflect',
                    )

train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)

# %% [markdown]
# # Models

# %% [markdown]
# ## Attention U-Net

# %%
'''
  Convolutional block with set parameters and activation layer after
'''

def convBlock(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)

  conv = Activation(act)(conv)
  return conv
  
'''
  Convolutional block with two conv layers and two activation layers
'''

def convBlock2(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)

  return conv
  
'''
  Attention block/mechanism
'''
def attention_block(x, gating, inter_shape, drop_rate=0.25):
   
    # Find shape of inputs
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    ## Process x vector and gating signal
    # x vector input and processing
    theta_x = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(x)
    theta_x = MaxPooling2D((2,2))(theta_x)
    shape_theta_x = K.int_shape(theta_x)

    # gating signal ""
    phi_g = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(gating)
    shape_phi_g = K.int_shape(phi_g)

    # Add components
    concat_xg = add([phi_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    # Apply convolution
    psi = Conv2D(1, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(act_xg)

    # Apply sigmoid activation
    sigmoid_xg = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)

    # UpSample and resample to correct size
    upsample_psi = UpSampling2D(interpolation='bilinear', size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)
    upsample_psi = tf.broadcast_to(upsample_psi, shape=shape_x)
    y = multiply([upsample_psi, x])

    return y


'''
  Attention U-Net model
'''

def UNetAM(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001, filter_base=16):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    inputs = Input(input_size, batch_size=1)

    ## Contraction phase
    conv = convBlock2(inputs, filter_base, 3)
    #conv0 = Dropout(drop_rate)(conv0)

    conv0 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv0 = convBlock2(conv0, 2 * filter_base, 3)

    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)
    conv1 = convBlock2(pool0, 4 * filter_base, 3)
    #conv1 = Dropout(drop_rate)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = convBlock2(pool1, 8 * filter_base, 3)
    #conv2 = Dropout(drop_rate)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = convBlock2(pool2, 16 * filter_base, 3)
    #conv3 = Dropout(drop_rate)(conv3)

    ## Expansion phase
    up4 = (Conv2DTranspose(8 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv3))
    merge4 = attention_block(conv2, conv3, 8 * filter_base, drop_rate) # Attention gate
    conv4 = concatenate([up4, merge4])
    conv4 = convBlock2(conv4, 8 * filter_base, 3)

    up5 = (Conv2DTranspose(4 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv4))
    merge5 = attention_block(conv1, conv4, 4 * filter_base, drop_rate) # Attention gate
    conv5 = concatenate([up5, merge5])
    conv5 = convBlock2(conv5, 4 * filter_base, 3)

    up6 = (Conv2DTranspose(2 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = attention_block(conv0, conv5, 2 * filter_base, drop_rate) # Attention gate
    conv6 = concatenate([up6, merge6])
    conv6 = convBlock2(conv6, 2 * filter_base, 3)

    up7 = (Conv2DTranspose(1 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = attention_block(conv, conv6, 1 * filter_base, drop_rate) # Attention gate
    conv7 = concatenate([up7, merge7])
    conv7 = concatenate([up7, conv])
    conv7 = convBlock2(conv7, 1 * filter_base, 3)

    ## Output layer
    out = convBlock(conv7, 1, 1, act='sigmoid')

    model = Model(inputs, out)

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])

    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNetAM().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(1, 512, 512, 3)]   0           []
#
#  conv2d (Conv2D)                (1, 512, 512, 16)    448         ['input_1[0][0]']
#
#  activation (Activation)        (1, 512, 512, 16)    0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (1, 512, 512, 16)    2320        ['activation[0][0]']
#
#  activation_1 (Activation)      (1, 512, 512, 16)    0           ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (1, 256, 256, 16)    0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (1, 256, 256, 32)    4640        ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (1, 256, 256, 32)    0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (1, 256, 256, 32)    9248        ['activation_2[0][0]']
#
#  activation_3 (Activation)      (1, 256, 256, 32)    0           ['conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (1, 128, 128, 32)   0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (1, 128, 128, 64)    18496       ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (1, 128, 128, 64)    0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (1, 128, 128, 64)    36928       ['activation_4[0][0]']
#
#  activation_5 (Activation)      (1, 128, 128, 64)    0           ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (1, 64, 64, 64)     0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (1, 64, 64, 128)     73856       ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (1, 64, 64, 128)     0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (1, 64, 64, 128)     147584      ['activation_6[0][0]']
#
#  activation_7 (Activation)      (1, 64, 64, 128)     0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (1, 32, 32, 128)    0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (1, 32, 32, 256)     295168      ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (1, 32, 32, 256)     0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (1, 32, 32, 256)     590080      ['activation_8[0][0]']
#
#  activation_9 (Activation)      (1, 32, 32, 256)     0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (1, 64, 64, 128)     16512       ['activation_7[0][0]']
#
#  conv2d_11 (Conv2D)             (1, 32, 32, 128)     32896       ['activation_9[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (1, 32, 32, 128)    0           ['conv2d_10[0][0]']
#
#  add (Add)                      (1, 32, 32, 128)     0           ['conv2d_11[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  activation_10 (Activation)     (1, 32, 32, 128)     0           ['add[0][0]']
#
#  conv2d_12 (Conv2D)             (1, 32, 32, 1)       129         ['activation_10[0][0]']
#
#  activation_11 (Activation)     (1, 32, 32, 1)       0           ['conv2d_12[0][0]']
#
#  up_sampling2d (UpSampling2D)   (1, 64, 64, 1)       0           ['activation_11[0][0]']
#
#  tf.broadcast_to (TFOpLambda)   (1, 64, 64, 128)     0           ['up_sampling2d[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (1, 64, 64, 128)    131200      ['activation_9[0][0]']
#  ose)
#
#  multiply (Multiply)            (1, 64, 64, 128)     0           ['tf.broadcast_to[0][0]',
#                                                                   'activation_7[0][0]']
#
#  concatenate (Concatenate)      (1, 64, 64, 256)     0           ['conv2d_transpose[0][0]',
#                                                                   'multiply[0][0]']
#
#  conv2d_13 (Conv2D)             (1, 64, 64, 128)     295040      ['concatenate[0][0]']
#
#  activation_12 (Activation)     (1, 64, 64, 128)     0           ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (1, 64, 64, 128)     147584      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (1, 64, 64, 128)     0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (1, 128, 128, 64)    4160        ['activation_5[0][0]']
#
#  conv2d_16 (Conv2D)             (1, 64, 64, 64)      8256        ['activation_13[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (1, 64, 64, 64)     0           ['conv2d_15[0][0]']
#
#  add_1 (Add)                    (1, 64, 64, 64)      0           ['conv2d_16[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  activation_14 (Activation)     (1, 64, 64, 64)      0           ['add_1[0][0]']
#
#  conv2d_17 (Conv2D)             (1, 64, 64, 1)       65          ['activation_14[0][0]']
#
#  activation_15 (Activation)     (1, 64, 64, 1)       0           ['conv2d_17[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (1, 128, 128, 1)    0           ['activation_15[0][0]']
#
#  tf.broadcast_to_1 (TFOpLambda)  (1, 128, 128, 64)   0           ['up_sampling2d_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (1, 128, 128, 64)   32832       ['activation_13[0][0]']
#  spose)
#
#  multiply_1 (Multiply)          (1, 128, 128, 64)    0           ['tf.broadcast_to_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  concatenate_1 (Concatenate)    (1, 128, 128, 128)   0           ['conv2d_transpose_1[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  conv2d_18 (Conv2D)             (1, 128, 128, 64)    73792       ['concatenate_1[0][0]']
#
#  activation_16 (Activation)     (1, 128, 128, 64)    0           ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (1, 128, 128, 64)    36928       ['activation_16[0][0]']
#
#  activation_17 (Activation)     (1, 128, 128, 64)    0           ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (1, 256, 256, 32)    1056        ['activation_3[0][0]']
#
#  conv2d_21 (Conv2D)             (1, 128, 128, 32)    2080        ['activation_17[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (1, 128, 128, 32)   0           ['conv2d_20[0][0]']
#
#  add_2 (Add)                    (1, 128, 128, 32)    0           ['conv2d_21[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  activation_18 (Activation)     (1, 128, 128, 32)    0           ['add_2[0][0]']
#
#  conv2d_22 (Conv2D)             (1, 128, 128, 1)     33          ['activation_18[0][0]']
#
#  activation_19 (Activation)     (1, 128, 128, 1)     0           ['conv2d_22[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (1, 256, 256, 1)    0           ['activation_19[0][0]']
#
#  tf.broadcast_to_2 (TFOpLambda)  (1, 256, 256, 32)   0           ['up_sampling2d_2[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (1, 256, 256, 32)   8224        ['activation_17[0][0]']
#  spose)
#
#  multiply_2 (Multiply)          (1, 256, 256, 32)    0           ['tf.broadcast_to_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  concatenate_2 (Concatenate)    (1, 256, 256, 64)    0           ['conv2d_transpose_2[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  conv2d_23 (Conv2D)             (1, 256, 256, 32)    18464       ['concatenate_2[0][0]']
#
#  activation_20 (Activation)     (1, 256, 256, 32)    0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (1, 256, 256, 32)    9248        ['activation_20[0][0]']
#
#  activation_21 (Activation)     (1, 256, 256, 32)    0           ['conv2d_24[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (1, 512, 512, 16)   2064        ['activation_21[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (1, 512, 512, 32)    0           ['conv2d_transpose_3[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_28 (Conv2D)             (1, 512, 512, 16)    4624        ['concatenate_4[0][0]']
#
#  activation_24 (Activation)     (1, 512, 512, 16)    0           ['conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (1, 512, 512, 16)    2320        ['activation_24[0][0]']
#
#  activation_25 (Activation)     (1, 512, 512, 16)    0           ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (1, 512, 512, 1)     17          ['activation_25[0][0]']
#
#  activation_26 (Activation)     (1, 512, 512, 1)     0           ['conv2d_30[0][0]']
#
# ==================================================================================================
# Total params: 2,006,292
# Trainable params: 2,006,292
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train on RGB feature data

# %% [markdown]
# ## Attention U-Net

# %%
# Train Attention U-Net model

am_unet = UNetAM()
save_model_am = ModelCheckpoint('unet-attention-loveda.hdf5', monitor='val_accuracy',verbose=1, save_best_only=True)

am_unet.fit(train,
            steps_per_epoch=100,
            epochs=50,
            validation_data=validation_df,
            callbacks=[save_model_am])
# Out:
# Epoch 1/50
# 2025-12-11 08:16:36.474911: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2025-12-11 08:16:37.156212: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 12.0
# 2025-12-11 08:16:37.156227: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2025-12-11 08:16:37.156265: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-12-11 08:17:53.973519: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#  99/100 [============================>.] - ETA: 0s - loss: 0.6901 - accuracy: 0.5668 - mse: 0.2482
# Epoch 1: val_accuracy improved from -inf to 0.63349, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 349s 54ms/step - loss: 0.6902 - accuracy: 0.5667 - mse: 0.2482 - val_loss: 0.6522 - val_accuracy: 0.6335 - val_mse: 0.2285
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.7731 - mse: 0.1754
# Epoch 2: val_accuracy improved from 0.63349 to 0.82152, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 5s 54ms/step - loss: 0.5319 - accuracy: 0.7731 - mse: 0.1754 - val_loss: 0.4096 - val_accuracy: 0.8215 - val_mse: 0.1286
# Epoch 3/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.4794 - accuracy: 0.8040 - mse: 0.1510
# Epoch 3: val_accuracy improved from 0.82152 to 0.86698, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 5s 49ms/step - loss: 0.4784 - accuracy: 0.8045 - mse: 0.1506 - val_loss: 0.3530 - val_accuracy: 0.8670 - val_mse: 0.1074
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3590 - accuracy: 0.8489 - mse: 0.1104
# Epoch 4: val_accuracy improved from 0.86698 to 0.88886, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 6s 56ms/step - loss: 0.3590 - accuracy: 0.8489 - mse: 0.1104 - val_loss: 0.2932 - val_accuracy: 0.8889 - val_mse: 0.0875
# Epoch 5/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3532 - accuracy: 0.8480 - mse: 0.1100
# Epoch 5: val_accuracy did not improve from 0.88886
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3529 - accuracy: 0.8484 - mse: 0.1099 - val_loss: 0.2956 - val_accuracy: 0.8880 - val_mse: 0.0884
# Epoch 6/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3585 - accuracy: 0.8461 - mse: 0.1114
# Epoch 6: val_accuracy did not improve from 0.88886
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3603 - accuracy: 0.8448 - mse: 0.1121 - val_loss: 0.3300 - val_accuracy: 0.8480 - val_mse: 0.1037
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3556 - accuracy: 0.8416 - mse: 0.1124
# Epoch 7: val_accuracy did not improve from 0.88886
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3556 - accuracy: 0.8416 - mse: 0.1124 - val_loss: 0.3946 - val_accuracy: 0.8107 - val_mse: 0.1260
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8545 - mse: 0.1044
# Epoch 8: val_accuracy improved from 0.88886 to 0.89564, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 5s 50ms/step - loss: 0.3355 - accuracy: 0.8545 - mse: 0.1044 - val_loss: 0.2662 - val_accuracy: 0.8956 - val_mse: 0.0788
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3806 - accuracy: 0.8348 - mse: 0.1197
# Epoch 9: val_accuracy did not improve from 0.89564
# 100/100 [==============================] - 5s 55ms/step - loss: 0.3806 - accuracy: 0.8348 - mse: 0.1197 - val_loss: 0.3208 - val_accuracy: 0.8616 - val_mse: 0.0988
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3529 - accuracy: 0.8470 - mse: 0.1097
# Epoch 10: val_accuracy did not improve from 0.89564
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3529 - accuracy: 0.8470 - mse: 0.1097 - val_loss: 0.3208 - val_accuracy: 0.8610 - val_mse: 0.0992
# Epoch 11/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3337 - accuracy: 0.8541 - mse: 0.1041
# Epoch 11: val_accuracy improved from 0.89564 to 0.89901, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 5s 47ms/step - loss: 0.3315 - accuracy: 0.8551 - mse: 0.1033 - val_loss: 0.2584 - val_accuracy: 0.8990 - val_mse: 0.0763
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8596 - mse: 0.1007
# Epoch 12: val_accuracy improved from 0.89901 to 0.90208, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 6s 57ms/step - loss: 0.3247 - accuracy: 0.8596 - mse: 0.1007 - val_loss: 0.2434 - val_accuracy: 0.9021 - val_mse: 0.0723
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8537 - mse: 0.1041
# Epoch 13: val_accuracy did not improve from 0.90208
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3327 - accuracy: 0.8537 - mse: 0.1041 - val_loss: 0.2803 - val_accuracy: 0.8799 - val_mse: 0.0852
# Epoch 14/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3220 - accuracy: 0.8629 - mse: 0.0992
# Epoch 14: val_accuracy did not improve from 0.90208
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3215 - accuracy: 0.8630 - mse: 0.0990 - val_loss: 0.3125 - val_accuracy: 0.8663 - val_mse: 0.0960
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8620 - mse: 0.0992
# Epoch 15: val_accuracy improved from 0.90208 to 0.90731, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 5s 47ms/step - loss: 0.3187 - accuracy: 0.8620 - mse: 0.0992 - val_loss: 0.2417 - val_accuracy: 0.9073 - val_mse: 0.0703
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8625 - mse: 0.0988
# Epoch 16: val_accuracy did not improve from 0.90731
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3178 - accuracy: 0.8625 - mse: 0.0988 - val_loss: 0.2450 - val_accuracy: 0.9015 - val_mse: 0.0730
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.8679 - mse: 0.0950
# Epoch 17: val_accuracy did not improve from 0.90731
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3061 - accuracy: 0.8679 - mse: 0.0950 - val_loss: 0.2479 - val_accuracy: 0.9051 - val_mse: 0.0730
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8714 - mse: 0.0928
# Epoch 18: val_accuracy did not improve from 0.90731
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2985 - accuracy: 0.8714 - mse: 0.0928 - val_loss: 0.2876 - val_accuracy: 0.8756 - val_mse: 0.0896
# Epoch 19/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.8531 - mse: 0.1047
# Epoch 19: val_accuracy did not improve from 0.90731
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3354 - accuracy: 0.8528 - mse: 0.1048 - val_loss: 0.2269 - val_accuracy: 0.9063 - val_mse: 0.0682
# Epoch 20/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.8601 - mse: 0.1023
# Epoch 20: val_accuracy did not improve from 0.90731
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3308 - accuracy: 0.8599 - mse: 0.1025 - val_loss: 0.2347 - val_accuracy: 0.9045 - val_mse: 0.0701
# Epoch 21/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2950 - accuracy: 0.8727 - mse: 0.0909
# Epoch 21: val_accuracy did not improve from 0.90731
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2949 - accuracy: 0.8729 - mse: 0.0909 - val_loss: 0.2264 - val_accuracy: 0.9071 - val_mse: 0.0681
# Epoch 22/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3187 - accuracy: 0.8575 - mse: 0.1002
# Epoch 22: val_accuracy did not improve from 0.90731
# 100/100 [==============================] - 5s 48ms/step - loss: 0.3199 - accuracy: 0.8566 - mse: 0.1007 - val_loss: 0.2324 - val_accuracy: 0.9069 - val_mse: 0.0692
# Epoch 23/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3037 - accuracy: 0.8658 - mse: 0.0950
# Epoch 23: val_accuracy improved from 0.90731 to 0.90904, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 6s 55ms/step - loss: 0.3043 - accuracy: 0.8654 - mse: 0.0952 - val_loss: 0.2414 - val_accuracy: 0.9090 - val_mse: 0.0700
# Epoch 24/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2959 - accuracy: 0.8708 - mse: 0.0921
# Epoch 24: val_accuracy did not improve from 0.90904
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2959 - accuracy: 0.8708 - mse: 0.0921 - val_loss: 0.2476 - val_accuracy: 0.8986 - val_mse: 0.0750
# Epoch 25/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8734 - mse: 0.0911
# Epoch 25: val_accuracy did not improve from 0.90904
# 100/100 [==============================] - 5s 50ms/step - loss: 0.2987 - accuracy: 0.8734 - mse: 0.0911 - val_loss: 0.2445 - val_accuracy: 0.9037 - val_mse: 0.0718
# Epoch 26/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2939 - accuracy: 0.8718 - mse: 0.0911
# Epoch 26: val_accuracy did not improve from 0.90904
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2937 - accuracy: 0.8721 - mse: 0.0911 - val_loss: 0.2619 - val_accuracy: 0.8899 - val_mse: 0.0802
# Epoch 27/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3080 - accuracy: 0.8623 - mse: 0.0973
# Epoch 27: val_accuracy improved from 0.90904 to 0.90959, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 5s 50ms/step - loss: 0.3080 - accuracy: 0.8623 - mse: 0.0973 - val_loss: 0.2168 - val_accuracy: 0.9096 - val_mse: 0.0651
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8782 - mse: 0.0878
# Epoch 28: val_accuracy improved from 0.90959 to 0.91362, saving model to unet-attention-loveda.hdf5
# 100/100 [==============================] - 5s 49ms/step - loss: 0.2847 - accuracy: 0.8782 - mse: 0.0878 - val_loss: 0.2148 - val_accuracy: 0.9136 - val_mse: 0.0633
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.8796 - mse: 0.0854
# Epoch 29: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2788 - accuracy: 0.8796 - mse: 0.0854 - val_loss: 0.2237 - val_accuracy: 0.9076 - val_mse: 0.0670
# Epoch 30/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3123 - accuracy: 0.8649 - mse: 0.0963
# Epoch 30: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3135 - accuracy: 0.8643 - mse: 0.0968 - val_loss: 0.2233 - val_accuracy: 0.9060 - val_mse: 0.0676
# Epoch 31/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2741 - accuracy: 0.8827 - mse: 0.0842
# Epoch 31: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2741 - accuracy: 0.8827 - mse: 0.0843 - val_loss: 0.2266 - val_accuracy: 0.9117 - val_mse: 0.0650
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 0.8874 - mse: 0.0812
# Epoch 32: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2671 - accuracy: 0.8874 - mse: 0.0812 - val_loss: 0.2263 - val_accuracy: 0.9073 - val_mse: 0.0672
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.8616 - mse: 0.0980
# Epoch 33: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 54ms/step - loss: 0.3130 - accuracy: 0.8616 - mse: 0.0980 - val_loss: 0.2392 - val_accuracy: 0.9063 - val_mse: 0.0703
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3148 - accuracy: 0.8605 - mse: 0.0988
# Epoch 34: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3148 - accuracy: 0.8605 - mse: 0.0988 - val_loss: 0.2389 - val_accuracy: 0.8980 - val_mse: 0.0728
# Epoch 35/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.8740 - mse: 0.0911
# Epoch 35: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 6s 60ms/step - loss: 0.2980 - accuracy: 0.8740 - mse: 0.0910 - val_loss: 0.2155 - val_accuracy: 0.9113 - val_mse: 0.0645
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8688 - mse: 0.0921
# Epoch 36: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 45ms/step - loss: 0.2946 - accuracy: 0.8688 - mse: 0.0921 - val_loss: 0.2385 - val_accuracy: 0.8955 - val_mse: 0.0736
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8713 - mse: 0.0928
# Epoch 37: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3000 - accuracy: 0.8713 - mse: 0.0928 - val_loss: 0.2562 - val_accuracy: 0.8972 - val_mse: 0.0771
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.8845 - mse: 0.0842
# Epoch 38: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2754 - accuracy: 0.8845 - mse: 0.0842 - val_loss: 0.2248 - val_accuracy: 0.9073 - val_mse: 0.0674
# Epoch 39/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.3213 - accuracy: 0.8606 - mse: 0.1001
# Epoch 39: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 49ms/step - loss: 0.3211 - accuracy: 0.8609 - mse: 0.1000 - val_loss: 0.2447 - val_accuracy: 0.8990 - val_mse: 0.0739
# Epoch 40/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2801 - accuracy: 0.8809 - mse: 0.0866
# Epoch 40: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2819 - accuracy: 0.8796 - mse: 0.0873 - val_loss: 0.2183 - val_accuracy: 0.9071 - val_mse: 0.0660
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2564 - accuracy: 0.8915 - mse: 0.0783
# Epoch 41: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 45ms/step - loss: 0.2564 - accuracy: 0.8915 - mse: 0.0783 - val_loss: 0.2270 - val_accuracy: 0.9025 - val_mse: 0.0688
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.8792 - mse: 0.0864
# Epoch 42: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2796 - accuracy: 0.8792 - mse: 0.0864 - val_loss: 0.2144 - val_accuracy: 0.9076 - val_mse: 0.0653
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.8788 - mse: 0.0860
# Epoch 43: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 48ms/step - loss: 0.2753 - accuracy: 0.8788 - mse: 0.0860 - val_loss: 0.2213 - val_accuracy: 0.9072 - val_mse: 0.0673
# Epoch 44/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2665 - accuracy: 0.8886 - mse: 0.0809
# Epoch 44: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 6s 56ms/step - loss: 0.2677 - accuracy: 0.8879 - mse: 0.0813 - val_loss: 0.2409 - val_accuracy: 0.9023 - val_mse: 0.0713
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.8720 - mse: 0.0896
# Epoch 45: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2871 - accuracy: 0.8720 - mse: 0.0896 - val_loss: 0.2159 - val_accuracy: 0.9097 - val_mse: 0.0650
# Epoch 46/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2781 - accuracy: 0.8812 - mse: 0.0849
# Epoch 46: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2761 - accuracy: 0.8821 - mse: 0.0842 - val_loss: 0.2083 - val_accuracy: 0.9124 - val_mse: 0.0629
# Epoch 47/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2799 - accuracy: 0.8755 - mse: 0.0875
# Epoch 47: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2788 - accuracy: 0.8761 - mse: 0.0872 - val_loss: 0.2313 - val_accuracy: 0.9102 - val_mse: 0.0672
# Epoch 48/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2764 - accuracy: 0.8794 - mse: 0.0850
# Epoch 48: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2774 - accuracy: 0.8789 - mse: 0.0853 - val_loss: 0.2127 - val_accuracy: 0.9128 - val_mse: 0.0633
# Epoch 49/50
#  99/100 [============================>.] - ETA: 0s - loss: 0.2590 - accuracy: 0.8898 - mse: 0.0795
# Epoch 49: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2569 - accuracy: 0.8908 - mse: 0.0789 - val_loss: 0.2340 - val_accuracy: 0.9071 - val_mse: 0.0687
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.8867 - mse: 0.0802
# Epoch 50: val_accuracy did not improve from 0.91362
# 100/100 [==============================] - 5s 48ms/step - loss: 0.2601 - accuracy: 0.8867 - mse: 0.0802 - val_loss: 0.2112 - val_accuracy: 0.9125 - val_mse: 0.0635

# %%
# Plot training history
plt.plot(am_unet.history.history['accuracy'], label='Training Accuracy')
plt.plot(am_unet.history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Attention U-Net Training History')
plt.legend()

# %% [markdown]
# # Import Models and Compute Metrics

# %% [markdown]
# ## RGB

# %%
# Load trained model
attention_unet = load_model('unet-attention-loveda.hdf5')

# %%
# Evaluate on validation data
am_unet_score = score_eval(attention_unet, validation_images, validation_masks)
am_unet_precision = precision_eval(attention_unet, validation_images, validation_masks)
am_unet_recall = recall_eval(attention_unet, validation_images, validation_masks)
am_unet_f1_score = f1_score_eval(attention_unet, validation_images, validation_masks)
# Out:
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
# Print eval results for each model
print('Attention U-Net accuracy: ', np.mean(am_unet_score), np.std(am_unet_score))
# Out:
# Attention U-Net accuracy:  0.9136159896850586 0.04965376012195155

# %%
# Print precision eval results for each model
print('Attention U-Net precision: ', np.mean(am_unet_precision), np.std(am_unet_precision))
# Out:
# Attention U-Net precision:  0.9200785080756363 0.04214630374423351

# %%
# Print recall eval results for each model
print('Attention U-Net recall: ', np.mean(am_unet_recall), np.std(am_unet_recall))
# Out:
# Attention U-Net recall:  0.9136159896850586 0.04965376012195155

# %%
# Print f1-score eval results for each model
print('Attention U-Net F1-score: ', np.mean(am_unet_f1_score))
# Out:
# Attention U-Net F1-score:  0.9168358609026883

# %%
# Visualize segmentation results on validation set
num_samples = min(2, len(validation_images)) 

fig, axes = plt.subplots(num_samples, 3, figsize=(12, 4 * num_samples))

for i in range(num_samples):
    # Get image and masks
    img = validation_images[i].reshape(512, 512, 3)
    true_mask = validation_masks[i].reshape(512, 512)
    
    # Predict
    pred_mask = attention_unet.predict(validation_images[i]).reshape(512, 512)
    pred_mask_binary = np.round(pred_mask)
    
    # Plot original image
    axes[i, 0].imshow(img)
    axes[i, 0].set_title('Original Image')
    axes[i, 0].axis('off')
    
    # Plot ground truth mask
    axes[i, 1].imshow(true_mask, cmap='gray')
    axes[i, 1].set_title('Ground Truth')
    axes[i, 1].axis('off')
    
    # Plot predicted mask
    axes[i, 2].imshow(pred_mask_binary, cmap='gray')
    axes[i, 2].set_title('Prediction')
    axes[i, 2].axis('off')

plt.suptitle('Validation Set Segmentation Results', fontsize=16)
plt.tight_layout()
plt.savefig('validation_results.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved to validation_results.png')
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# Saved to validation_results.png

# %% [markdown]
# # Produce metric datasets for export

# %% [markdown]
# ## RGB data

# %%
import pandas as pd

metrics_3d = {
    'classifier': ['Attention U-Net'],
    'accuracy': [np.mean(am_unet_score)],
    'precision': [np.mean(am_unet_precision)],
    'recall': [np.mean(am_unet_recall)],
    'f1_score': [np.mean(am_unet_f1_score)],
    'accuracy_std': [np.std(am_unet_score)],
    'precision_std': [np.std(am_unet_precision)],
    'recall_std': [np.std(am_unet_recall)]
}

metrics_3d = pd.DataFrame(metrics_3d)
metrics_3d.to_csv('metrics_loveda.csv')
print(metrics_3d)
# Out:
#         classifier  accuracy  precision    recall  f1_score  accuracy_std  \
# 0  Attention U-Net  0.913616   0.920079  0.913616  0.916836      0.049654
#
#    precision_std  recall_std
# 0       0.042146    0.049654
